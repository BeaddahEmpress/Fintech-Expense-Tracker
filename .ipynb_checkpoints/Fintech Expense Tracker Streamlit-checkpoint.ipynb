# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\lerato motloung\anaconda3\lib\site-packages (1.45.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from streamlit) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from streamlit) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\lerato motloung\anaconda3\lib\site-packages (from streamlit) (2.1.3)
# Requirement already satisfied: packaging<25,>=20 in c:\users\lerato motloung\anaconda3\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from streamlit) (11.1.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\lerato motloung\anaconda3\lib\site-packages (from streamlit) (5.29.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from streamlit) (19.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\lerato motloung\anaconda3\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\lerato motloung\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from streamlit) (4.16.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\lerato motloung\anaconda3\lib\site-packages (from streamlit) (4.0.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\lerato motloung\anaconda3\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\lerato motloung\anaconda3\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in c:\users\lerato motloung\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\lerato motloung\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (1.31.0)
# Requirement already satisfied: colorama in c:\users\lerato motloung\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\lerato motloung\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\lerato motloung\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lerato motloung\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lerato motloung\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lerato motloung\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lerato motloung\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lerato motloung\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lerato motloung\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lerato motloung\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.4.26)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\lerato motloung\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\lerato motloung\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\lerato motloung\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: six>=1.5 in c:\users\lerato motloung\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)

# %%
# !pip install supabase
# Out:
# Requirement already satisfied: supabase in c:\users\lerato motloung\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: realtime==2.31.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from supabase) (2.31.0)
# Requirement already satisfied: supabase-functions==2.31.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from supabase) (2.31.0)
# Requirement already satisfied: storage3==2.31.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from supabase) (2.31.0)
# Requirement already satisfied: supabase-auth==2.31.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from supabase) (2.31.0)
# Requirement already satisfied: postgrest==2.31.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from supabase) (2.31.0)
# Requirement already satisfied: httpx<0.29,>=0.26 in c:\users\lerato motloung\anaconda3\lib\site-packages (from supabase) (0.28.1)
# Requirement already satisfied: yarl>=1.22.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from supabase) (1.24.5)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from postgrest==2.31.0->supabase) (2.1.0)
# Requirement already satisfied: pydantic<3.0,>=1.9 in c:\users\lerato motloung\anaconda3\lib\site-packages (from postgrest==2.31.0->supabase) (2.13.5)
# Requirement already satisfied: typing-extensions>=4.14.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from realtime==2.31.0->supabase) (4.16.0)
# Requirement already satisfied: websockets<16,>=11 in c:\users\lerato motloung\anaconda3\lib\site-packages (from realtime==2.31.0->supabase) (15.0.1)
# Requirement already satisfied: pyjwt>=2.12.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.12.0->supabase-auth==2.31.0->supabase) (2.14.0)
# Requirement already satisfied: strenum>=0.4.15 in c:\users\lerato motloung\anaconda3\lib\site-packages (from supabase-functions==2.31.0->supabase) (0.4.15)
# Requirement already satisfied: anyio in c:\users\lerato motloung\anaconda3\lib\site-packages (from httpx<0.29,>=0.26->supabase) (4.7.0)
# Requirement already satisfied: certifi in c:\users\lerato motloung\anaconda3\lib\site-packages (from httpx<0.29,>=0.26->supabase) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\lerato motloung\anaconda3\lib\site-packages (from httpx<0.29,>=0.26->supabase) (1.0.9)
# Requirement already satisfied: idna in c:\users\lerato motloung\anaconda3\lib\site-packages (from httpx<0.29,>=0.26->supabase) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\lerato motloung\anaconda3\lib\site-packages (from httpcore==1.*->httpx<0.29,>=0.26->supabase) (0.16.0)
# Requirement already satisfied: h2<5,>=3 in c:\users\lerato motloung\anaconda3\lib\site-packages (from httpx[http2]<0.29,>=0.26->postgrest==2.31.0->supabase) (4.4.1)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\users\lerato motloung\anaconda3\lib\site-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.31.0->supabase) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.2 in c:\users\lerato motloung\anaconda3\lib\site-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.31.0->supabase) (4.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from pydantic<3.0,>=1.9->postgrest==2.31.0->supabase) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.5 in c:\users\lerato motloung\anaconda3\lib\site-packages (from pydantic<3.0,>=1.9->postgrest==2.31.0->supabase) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\lerato motloung\anaconda3\lib\site-packages (from pydantic<3.0,>=1.9->postgrest==2.31.0->supabase) (0.4.4)
# Requirement already satisfied: packaging in c:\users\lerato motloung\anaconda3\lib\site-packages (from deprecation>=2.1.0->postgrest==2.31.0->supabase) (24.2)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.12.0->supabase-auth==2.31.0->supabase) (44.0.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\lerato motloung\anaconda3\lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.12.0->supabase-auth==2.31.0->supabase) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\lerato motloung\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.12.0->supabase-auth==2.31.0->supabase) (2.21)
# Requirement already satisfied: multidict>=4.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from yarl>=1.22.0->supabase) (6.1.0)
# Requirement already satisfied: propcache>=0.2.1 in c:\users\lerato motloung\anaconda3\lib\site-packages (from yarl>=1.22.0->supabase) (0.3.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\lerato motloung\anaconda3\lib\site-packages (from anyio->httpx<0.29,>=0.26->supabase) (1.3.0)

# %%
# !pip install plotly pandas
# Out:
# Requirement already satisfied: plotly in c:\users\lerato motloung\anaconda3\lib\site-packages (5.24.1)
# Requirement already satisfied: pandas in c:\users\lerato motloung\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in c:\users\lerato motloung\anaconda3\lib\site-packages (from plotly) (24.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\lerato motloung\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lerato motloung\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lerato motloung\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lerato motloung\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\lerato motloung\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import streamlit as st
import pandas as pd
import plotly.express as px

print("Everything installed successfully")
# Out:
# Everything installed successfully

# %%
from supabase import create_client
url = "https://ltzghyyhqglwqcwusmlt.supabase.co"
key = "sb_publishable_o-FY0g6pPRvMD4RySMY4tA_f6L_Rbxp"

supabase = create_client(url, key)
print("Connected successfully")
# Out:
# Connected successfully

# %%
response = supabase.table("transactions").select("*").execute()

print(response.data[:5])
# Out:
# [{'id': 1, 'transaction_date': '2025-07-28', 'description': 'Fuel Station', 'category': 'Transport', 'amount': 3662.43}, {'id': 2, 'transaction_date': '2025-12-20', 'description': 'Discovery', 'category': 'Insurance', 'amount': 4190.68}, {'id': 3, 'transaction_date': '2025-05-01', 'description': 'Clicks', 'category': 'Shopping', 'amount': 1373.51}, {'id': 4, 'transaction_date': '2025-05-25', 'description': 'KFC', 'category': 'Food', 'amount': 4256.62}, {'id': 5, 'transaction_date': '2026-05-04', 'description': 'Pick n Pay', 'category': 'Food', 'amount': 1466.17}]

# %%
response = supabase.table("transactions").select("*").execute()

print(len(response.data))
# Out:
# 1000

# %%
print(supabase)
# Out:
# <supabase._sync.client.Client object at 0x00000217A08AE120>

# %%
print(url)
print(key[:20])
# Out:
# https://ltzghyyhqglwqcwusmlt.supabase.co
# sb_publishable_o-FY0

# %%
response = supabase.table("transactions").select("*").execute()

# %%
# !pip show supabase
# Out:
# Name: supabase
# Version: 2.31.0
# Summary: Supabase client for Python.
# Home-page: https://github.com/supabase/supabase-py
# Author: Joel Lee, Leon Fedden, Daniel Reinón García, Leynier Gutiérrez González, Anand, Andrew Smith
# Author-email: Joel Lee <joel@joellee.org>, Leon Fedden <leonfedden@gmail.com>, Daniel Reinón García <danielreinon@outlook.com>, Leynier Gutiérrez González <leynier41@gmail.com>, Andrew Smith <a.smith@silentworks.co.uk>
# License-Expression: MIT
# Location: C:\Users\Lerato Motloung\anaconda3\Lib\site-packages
# Requires: httpx, postgrest, realtime, storage3, supabase-auth, supabase-functions, yarl
# Required-by:

# %%
import streamlit as st
import pandas as pd
from supabase import create_client

url = "https://ltzghyyhqglwqcwusmlt.supabase.co"
key = "sb_publishable_o-FY0g6pPRvMD4RySMY4tA_f6L_Rbxp"

supabase = create_client(url, key)

response = supabase.table("transactions").select("*").execute()

df = pd.Dataframe(response.data)

st.title("Fintech Expense Tracker")

st.dataframe(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 12
#       8 supabase = create_client(url, key)
#      10 response = supabase.table("transactions").select("*").execute()
# ---> 12 df = pd.Dataframe(response.data)
#      14 st.title("Fintech Expense Tracker")
#      16 st.dataframe(df)
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
import pandas as pd

print(pd.__version__)
print(pd.__file__)
print(hasattr(pd, "Dataframe"))
# Out:
# 2.2.3
# C:\Users\Lerato Motloung\anaconda3\Lib\site-packages\pandas\__init__.py
# False

# %%
# !pip install --upgrade--force-reinstall pandas
# Out:
# Usage:
#   pip install [options] <requirement specifier> [package-index-options] ...
#   pip install [options] -r <requirements file> [package-index-options] ...
#   pip install [options] [-e] <vcs project url> ...
#   pip install [options] [-e] <local project path> ...
#   pip install [options] <archive url/path> ...
#
# no such option: --upgrade--force-reinstall

# %%
conda install pandas--force-reinstall
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'C:\Users\Lerato' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pandas as pd

print(pd.__file__)
print(dir(pd)[:30])
# Out:
# C:\Users\Lerato Motloung\anaconda3\Lib\site-packages\pandas\__init__.py
# ['ArrowDtype', 'BooleanDtype', 'Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Flags', 'Float32Dtype', 'Float64Dtype', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NA', 'NaT', 'NamedAgg', 'Period']

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\Lerato Motloung
# ['-1.14-windows.xml', '.anaconda', '.conda', '.condarc', '.continuum', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.spyder-py3', 'anaconda3', 'AppData', 'Application Data', 'Class Exercise 02 Feb.ipynb', 'Class Exercises.ipynb', 'Class Recap for 12 Jan week 2026.ipynb', 'Contacts', 'Cookies', 'DataScience Ecosystem.ipynb', 'Desktop', 'Documents', 'Downloads', 'Exam revision.ipynb', 'Favorites', 'Fintech Expense Tracker Streamlit.ipynb', 'Fintech Expense Tracker.ipynb', 'IntelGraphicsProfiles', 'Links', 'Local Settings', 'Microsoft', 'Mini Project December-Copy1.ipynb', 'Mini Project December.ipynb', 'Mini Project Group B2.ipynb', 'Music', 'My Documents', 'NetHood', 'noaa-weather-data-v1.ipynb', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{5373b21f-9d07-11f0-b23e-189341088d8c}.TM.blf', 'NTUSER.DAT{5373b21f-9d07-11f0-b23e-189341088d8c}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{5373b21f-9d07-11f0-b23e-189341088d8c}.TMContainer00000000000000000002.regtrans-ms', 'NTUSER.DAT{f1ba7b45-ef26-11ef-b21a-d0b34e491b1d}.TM.blf', 'NTUSER.DAT{f1ba7b45-ef26-11ef-b21a-d0b34e491b1d}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{f1ba7b45-ef26-11ef-b21a-d0b34e491b1d}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'Pictures', 'pl-300.pdf', 'PrintHood', 'Python Mini Project Final.ipynb', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'Templates', 'transaction.csv', 'transactions.csv', 'transactions_final.csv', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled10.ipynb', 'Untitled11.ipynb', 'Untitled12.ipynb', 'Untitled13.ipynb', 'Untitled14.ipynb', 'Untitled2.ipynb', 'Untitled3.ipynb', 'Untitled4.ipynb', 'Untitled5.ipynb', 'Untitled6.ipynb', 'Untitled7.ipynb', 'Untitled8.ipynb', 'Untitled9.ipynb', 'Videos']

# %%
import pandas as pd

print("Pandas version", pd.__version__)
print("Has DataFrame:", hasattr(pd, "DataFrame"))
print("DataFrame:", getattr(pd, "DataFrame", "MISSING"))
# Out:
# Pandas version 2.2.3
# Has DataFrame: True
# DataFrame: <class 'pandas.core.frame.DataFrame'>

# %%
df = pd.DataFrame(response.data)

print(df.head())
# Out:
#    id transaction_date   description   category   amount
# 0   1       2025-07-28  Fuel Station  Transport  3662.43
# 1   2       2025-12-20     Discovery  Insurance  4190.68
# 2   3       2025-05-01        Clicks   Shopping  1373.51
# 3   4       2025-05-25           KFC       Food  4256.62
# 4   5       2026-05-04    Pick n Pay       Food  1466.17

# %%
import pandas as pd

df = pd.DataFrame(response.data)

print(df.head())
# Out:
#    id transaction_date   description   category   amount
# 0   1       2025-07-28  Fuel Station  Transport  3662.43
# 1   2       2025-12-20     Discovery  Insurance  4190.68
# 2   3       2025-05-01        Clicks   Shopping  1373.51
# 3   4       2025-05-25           KFC       Food  4256.62
# 4   5       2026-05-04    Pick n Pay       Food  1466.17
